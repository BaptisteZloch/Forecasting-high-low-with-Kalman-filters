# %%
from typing import Union
import numpy as np
import pandas as pd
import numpy.typing as npt
from typing import Tuple
from tqdm import tqdm
from matplotlib import pyplot as plt
from simulations.DDSSM import DDSSM
from utility.math_equations import (
    compute_currrent_step_log_price,
    compute_next_step_log_vol,
)

from filters.unscented_kalman_filter import UnscentedKalmanFilter
from utility.constants import BUSINESS_DAYS

# %%
# Seed for reproducibility
np.random.seed(2)

# Paramètres du modèle
T=5
N=int(T * BUSINESS_DAYS)
mu = [np.random.random_sample() for i in range(N)]
kappa = 2.0
theta = 0.04
xi = 0.1
rho = -0.5
p=1/2 # Modèle de Hesson
# Modèle 
H = DDSSM(N,T,p,mu,kappa,theta,xi,rho)

vol, prix = DDSSM.simulate(H)

df=pd.DataFrame({"vol":vol,"prices":prix})
df
# Out:
#            vol       prices
# 0     0.040000   100.000000
# 1     0.040000   100.000000
# 2     0.039574    99.833941
# 3     0.040126   100.174498
# 4     0.039646   100.197717
# ...        ...          ...
# 1255  0.024306  1034.544838
# 1256  0.023980  1035.855336
# 1257  0.024109  1039.873606
# 1258  0.023635  1040.992912
# 1259  0.023785  1045.050541
#
# [1260 rows x 2 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6228\824669019.py in ?()
# ----> 2 fig, ax = plt.subplots(2, 1, figsize=(20, 10))
#       3 ax[0].plot(df.N, df.prices, label="Synthetic Stock Price")
#       4 ax[0].set_xlabel("Time")
#       5 ax[0].set_ylabel("Stock Price")
#
# c:\Users\milos\OneDrive\Bureau\M2\Gestion quant\projet KALMAN\Forecasting-high-low-with-Kalman-filters\.venv\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5898             and name not in self._accessors
#    5899             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'N'
